# %%
with open("/Users/z5601757/Documents/ResearchProject/Vision Language Model Project/ptb-diagnostic-ecg-database-1.0.0/patient002/s0015lre.hea", "r") as file:
    header_data_002 = file.readlines()
print("".join(header_data_002))
# Out:
# s0015lre 15 1000 115200
# s0015lre.dat 16 2000 16 0 547 26687 0 i
# s0015lre.dat 16 2000 16 0 -70 21312 0 ii
# s0015lre.dat 16 2000 16 0 -616 -20394 0 iii
# s0015lre.dat 16 2000 16 0 -238 9018 0 avr
# s0015lre.dat 16 2000 16 0 582 -9554 0 avl
# s0015lre.dat 16 2000 16 0 -343 542 0 avf
# s0015lre.dat 16 2000 16 0 1360 26959 0 v1
# s0015lre.dat 16 2000 16 0 666 2258 0 v2
# s0015lre.dat 16 2000 16 0 782 31404 0 v3
# s0015lre.dat 16 2000 16 0 109 29829 0 v4
# s0015lre.dat 16 2000 16 0 -767 -2737 0 v5
# s0015lre.dat 16 2000 16 0 -396 -517 0 v6
# s0015lre.xyz 16 2000 16 0 -641 31013 0 vx
# s0015lre.xyz 16 2000 16 0 -358 24775 0 vy
# s0015lre.xyz 16 2000 16 0 -9 22435 0 vz
#
# # age: 58
# # sex: female
# # ECG date: 17/10/1990
#
# # Diagnose:
# # Reason for admission: Myocardial infarction
# # Acute infarction (localization): anterior
# # Former infarction (localization): no
# # Additional diagnoses: Arterial hypertension, Adiposis hepatis, Gastritis
# # Smoker: yes
# ...

# %%
import wfdb

record = wfdb.rdrecord("/Users/z5601757/Documents/ResearchProject/Vision Language Model Project/ptb-diagnostic-ecg-database-1.0.0/patient002/s0015lre")
wfdb.plot_wfdb(record)

# %%
# with open("/Users/z5601757/Documents/ResearchProject/Vision Language Model Project/ptb-diagnostic-ecg-database-1.0.0/patient002/s0015lre.xyz", "r") as file:
#     xyz_data = file.readlines()
import numpy as np

data = np.loadtxt("/Users/z5601757/Documents/ResearchProject/Vision Language Model Project/ptb-diagnostic-ecg-database-1.0.0/patient002/s0015lre.xyz")
print(data)
# print("".join(xyz_data))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 with open("/Users/z5601757/Documents/ResearchProject/Vision Language Model Project/ptb-diagnostic-ecg-database-1.0.0/patient002/s0015lre.xyz", "r") as file:
# ----> 2     xyz_data = file.readlines()
#       3 print("".join(xyz_data))
#
# File /opt/anaconda3/envs/vscode_env/lib/python3.10/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xfd in position 1: invalid start byte
